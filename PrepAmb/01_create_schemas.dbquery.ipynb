-- %%
CREATE SCHEMA IF NOT EXISTS instacart_dev.bronze;
CREATE SCHEMA IF NOT EXISTS instacart_dev.silver;
CREATE SCHEMA IF NOT EXISTS instacart_dev.gold;

CREATE SCHEMA IF NOT EXISTS instacart_prod.bronze;
CREATE SCHEMA IF NOT EXISTS instacart_prod.silver;
CREATE SCHEMA IF NOT EXISTS instacart_prod.gold;
